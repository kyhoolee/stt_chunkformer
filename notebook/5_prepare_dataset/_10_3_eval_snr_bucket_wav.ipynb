# %%
# ! pip install editdistance

# %%
from chunkformer_vpb.training.train import evaluate_from_meta_by_bucket

evaluate_from_meta_by_bucket("../../../vpb_dataset/manifest_vpb_right/train_meta_right_2_filtered_snr.json")
# Out:
# ===== OVERALL =====
# 📊 Tổng số mẫu: 3289
# 🎯 WER trung bình: 34.07%
# 🅲 CER trung bình: 31.15%
# 🌐 WER toàn cục : 24.31%
# 🌐 CER toàn cục : 19.14%
#
# ===== BY SNR BUCKET =====
# [clean]
#   📦 samples        : 2396
#   🎯 sample-avg WER : 34.06%
#   🅲 sample-avg CER : 31.27%
#   🌐 global WER     : 24.10%
#   🌐 global CER     : 18.96%
#
# [mid]
#   📦 samples        : 627
#   🎯 sample-avg WER : 32.79%
#   🅲 sample-avg CER : 29.40%
#   🌐 global WER     : 23.60%
#   🌐 global CER     : 18.84%
#
# [noisy]
#   📦 samples        : 265
#   🎯 sample-avg WER : 36.95%
#   🅲 sample-avg CER : 33.73%
#   🌐 global WER     : 28.05%
#   🌐 global CER     : 22.01%
#
# [unknown]
#   📦 samples        : 1
#   🎯 sample-avg WER : 100.00%
#   🅲 sample-avg CER : 150.00%
#   🌐 global WER     : 100.00%
#   🌐 global CER     : 150.00%

# %%
from chunkformer_vpb.training.train import evaluate_from_meta_by_bucket

evaluate_from_meta_by_bucket("../../../vpb_dataset/manifest_vpb_right/valid_meta_filtered_snr.json")
# Out:
# ===== OVERALL =====
# 📊 Tổng số mẫu: 706
# 🎯 WER trung bình: 36.50%
# 🅲 CER trung bình: 32.59%
# 🌐 WER toàn cục : 27.64%
# 🌐 CER toàn cục : 22.00%
#
# ===== BY SNR BUCKET =====
# [clean]
#   📦 samples        : 436
#   🎯 sample-avg WER : 37.01%
#   🅲 sample-avg CER : 32.48%
#   🌐 global WER     : 26.93%
#   🌐 global CER     : 21.14%
#
# [mid]
#   📦 samples        : 181
#   🎯 sample-avg WER : 33.03%
#   🅲 sample-avg CER : 29.67%
#   🌐 global WER     : 26.19%
#   🌐 global CER     : 21.05%
#
# [noisy]
#   📦 samples        : 89
#   🎯 sample-avg WER : 41.04%
#   🅲 sample-avg CER : 39.02%
#   🌐 global WER     : 34.66%
#   🌐 global CER     : 28.67%

# %%
from chunkformer_vpb.training.train import evaluate_detail_bucket

report = evaluate_detail_bucket(
    "../../../vpb_dataset/manifest_vpb_right/valid_meta_filtered_snr.json"
)

print(report)
# Out:
# Processed 10 samples: clean | WER: 0.00% | CER: 0.00%
# Processed 20 samples: clean | WER: 0.00% | CER: 0.00%
# Processed 30 samples: mid | WER: 100.00% | CER: 85.71%
# Processed 40 samples: clean | WER: 0.00% | CER: 0.00%
# Processed 50 samples: clean | WER: 31.58% | CER: 31.67%
# Processed 60 samples: noisy | WER: 100.00% | CER: 100.00%
# Processed 70 samples: clean | WER: 33.33% | CER: 22.50%
# Processed 80 samples: clean | WER: 50.00% | CER: 33.33%
# Processed 90 samples: clean | WER: 33.33% | CER: 29.63%
# Processed 100 samples: clean | WER: 50.00% | CER: 33.33%
# Processed 110 samples: clean | WER: 100.00% | CER: 80.00%
# Processed 120 samples: noisy | WER: 0.00% | CER: 0.00%
# Processed 130 samples: clean | WER: 0.00% | CER: 0.00%
# Processed 140 samples: noisy | WER: 66.67% | CER: 58.06%
# Processed 150 samples: mid | WER: 23.53% | CER: 24.07%
# Processed 160 samples: noisy | WER: 14.29% | CER: 6.25%
# Processed 170 samples: noisy | WER: 25.00% | CER: 25.00%
# ...
